# %% [markdown]
# # IceCube представлял в виде косинуса и синуса

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
#from sklearn.metrics import r2_score
device = torch.device('cuda:0') if torch.cuda.is_available else torch.device('cpu')
print(device)
# %matplotlib inline
np.random.seed(1)
plt.style.use("seaborn-talk") #"classic" "seaborn-talk" "seaborn"
path_to_h5 =  "/home/leonov/Baikal/Cut_8_nu/APRIL/Ordered/Data/mc_baikal_norm_cut-8_ordered_equal_big.h5"

# можно отделить хвост и отдельно прогнать его по другой сетке
def make_trainset_noxyz(i, di = 1, tr_set_len = 128,Batch_size = 64):
    with h5py.File(path_to_h5, 'r') as hf:
            Data = hf['train/data/'][i*int(tr_set_len) : (i+di)*int(tr_set_len),:32]
            Polar=hf["/train/ev_chars"][i*int(tr_set_len) : (i+di)*int(tr_set_len),0]*(np.pi)/180
            #Azimut=hf["/train/ev_chars"][i*int(tr_set_len) : (i+di)*int(tr_set_len),1]*(np.pi)/180
            x=np.expand_dims(np.sin(Polar),axis=1)
            y=np.expand_dims(np.cos(Polar),axis=1)
            target=torch.FloatTensor(np.concatenate((x,y) ,axis=1))
            Data = torch.FloatTensor(Data.swapaxes(1, -1)) # надо,т.к. второй индекс должен быть количеством   последовательностей
            trainDataset = torch.utils.data.TensorDataset(Data, target)
            trainLoader = torch.utils.data.DataLoader(dataset = trainDataset, batch_size=Batch_size) #,sampler = sampler    
    return  trainLoader
def make_valset_noxyz(i=0, di = 1, tr_set_len = 1000, Batch_size = 64):
    with h5py.File(path_to_h5, 'r') as hf:
            Data = hf['val/data/'][i*int(tr_set_len) : (i+di)*int(tr_set_len),:32] # ибо очень редко как то задействовано более чем 32 OM
            Data = torch.FloatTensor(Data.swapaxes(1, -1)) 
            Polar=hf["/val/ev_chars"][i*int(tr_set_len) : (i+di)*int(tr_set_len),0]*(np.pi)/180
            x=np.expand_dims(np.sin(Polar),axis=1)
            y=np.expand_dims(np.cos(Polar),axis=1)
            target=torch.FloatTensor(np.concatenate((x,y) ,axis=1))
            testDataset = torch.utils.data.TensorDataset(Data, target)
            testLoader = torch.utils.data.DataLoader(dataset = testDataset, batch_size=Batch_size)
    return testLoader
# вектора в углы
def v_to_angles( Predicted, Real,
                p_hist, p_error_hist,
                p_error_angle_cut_hist,
                min_angle = 10., max_angle = 60.): 
    v_pred = torch.nn.functional.normalize(Predicted.detach()) # нормализую
    polar_predicted = torch.acos(v_pred[:,-1])/(np.pi)*180 
    polar_real = torch.acos(Real[:,-1])/(np.pi)*180 
 
    for pol_pred, pol_real in zip(polar_predicted, polar_real):
        p_error_hist[round(abs((pol_pred-pol_real).item()),1)] += 1
        # for certain angles !!!!!!!!!!!!!!!!!!!!!!!
        if (pol_real.item() >= min_angle) and (pol_real.item() <= max_angle): 
            p_error_angle_cut_hist[round(abs((pol_pred-pol_real).item()),1)] += 1
        p_hist[pol_pred.short().item()] += 1
    

def loss_plot(list_test, list_train , path , save = True):
    plt.figure(figsize=(9,6))
    plt.plot(np.arange(len(list_test)), list_test, label='val', linewidth=2)
    plt.plot(np.arange(len(list_train)), list_train, label='train', linewidth=2)
    plt.title('Loss_plot')
    plt.xlabel('iterations')
    plt.ylabel('Loss')
    plt.legend()
    if save == True:
        plt.savefig(path)
    plt.show()
def res_plot(train_dict,val_dict, path = None,save = True, res_or_polar = "Resolution " ,size= 13):
    plt.figure(figsize=(13,5))
    colours=["red","red"]
    names = ["train" , "val"]
    for i, d in enumerate([train_dict,val_dict]):
        plt.subplot(1,2,i+1)
        s = sum(d.values())
        prep_inter_s ,inter_s = 0, 0
        res_50, res_68 =0,0
        for key in list(d.keys()):
            if inter_s/s >= 0.68:
                alpha = (inter_s-0.68*s)/(inter_s-prep_inter_s) # alpha*inter_s+(1-alpha)*prep_inter_s == 0.68*s
                res_68 =round(key + 0.1*alpha,2)  #alpha*(key-0.1)+(1-alpha)*(key)
                break
            if inter_s/s >= 0.5 and res_50 == 0:
                alpha = (inter_s-0.5*s)/(inter_s-prep_inter_s)
                res_50 =round(key + 0.1*alpha,2)
            prep_inter_s = inter_s 
            inter_s  += d[key]  
        a=plt.step(list(d.keys())[:300], list(d.values())[:300], color=colours[i],alpha = 0.6)
        plt.bar(res_50, max(d.values()), width=0.5,label=names[i] + "50%" + res_or_polar +"= "+str(res_50),
                color="yellow" , alpha =0.7 )
        plt.bar(res_68, max(d.values()), width=0.5,label=names[i] + "68%" + res_or_polar +" = "+str(res_68) ,
                color="orange",alpha = 0.7)
        plt.legend(); plt.suptitle(res_or_polar,fontsize =size+3)
        plt.xlabel(res_or_polar + "in_grad",fontsize= size); plt.title(res_or_polar + names[i],fontsize= size)
    if save == True:
        plt.savefig(path) 
    plt.show()

def angle_hist(hist_polar,path, save =True,size= 13,name = "train"): #hist_azimut
    with h5py.File(path_to_h5, 'r') as hf:
        plt.figure(figsize= (13,6))
        sum_value = sum(hist_polar.values())
        Polar=hf["/"+name+"/ev_chars"][ : ,0] 
        #Azimut=hf["/"+name+"/ev_chars"][ : ,1]
        #plt.subplot(2,1,1)
        plt.hist(Polar,bins=180,label=name+" Polar",density=True,histtype="step",color="blue")
        plt.bar(list(hist_polar.keys())[:100], np.array(list(hist_polar.values())[:100])/sum_value, 
                color="red",label=name+" Polar_Predicted")
        plt.legend()
        plt.xlabel("Polar_Angle",fontsize= size); plt.title(name+"_Polar",fontsize= size)
        if save == True:
            plt.savefig(path) 
        plt.show()
# Out:
# cuda:0

# %%
def fitting(model, scheduler_Exp, scheduler_MultiStep , optimizer,
        min_angle = 10. ,max_angle = 60.0,
        epochs_num = 25, batch_size = 64,
        criterion=torch.nn.L1Loss(),
        save_weights = True, save_plot = True, save_resolution = True,  save_angles = True, save_polar_error = True,   
        suffix = "Nu_MAE_Only_Polar_Res_Conv_",
        path_begin = "/home/leonov/Baikal/Cut_8_nu/APRIL/Ordered"):
    
    tr_set_len = 2*512*100
    seq = [j for j in range(int( 1881011/tr_set_len))]
    print('Num of sub-epochs in Epoch = ', len(seq), '\n')
    len_seq = len(seq)
    loss_train = []
    loss_test = []
    
    # здесь будут polar error всех событий
    hist_train_polar_error = {round(k,1):0 for k in np.arange(0.0, 180, 0.1)} 
    hist_val_polar_error = {round(k,1):0 for k in np.arange(0.0, 180, 0.1)}
    
    # здесь будут polar error углов от min_angle до max_angle
    hist_train_polar_error_angle_cut = {round(k,1):0 for k in np.arange(0.0, 180., 0.1)} 
    hist_val_polar_error_angle_cut = {round(k,1):0 for k in np.arange(0.0, 180., 0.1)} 
    
    # гистограммы  предсказанных углов для сравнения с реальным распределением     
    hist_train_polar = {k:0 for k in np.arange(-5, 181, 1)}
    hist_train_azimut = {k:0 for k in np.arange(-5, 361, 1)}
    hist_val_polar = {k:0 for k in np.arange(-5, 181, 1)} 
    hist_val_azimut = {k:0 for k in np.arange(-5, 361, 1)}  
    num = 0
    for n in range(1, epochs_num+1):
        #training
        print('\n','Indeed Epoch = ', n)
        for i in seq:
            train_Loader = make_trainset_noxyz(i,1,tr_set_len,Batch_size = batch_size)
            for x_batch,y_batch in train_Loader:
                optimizer.zero_grad()
                outp = model(x_batch.to(device).float())
                loss =   criterion(outp,y_batch.to(device).float())
                loss.backward()
                optimizer.step()
                # полученный вектор направления превращаю в углы и добавляю в гистограммы
                if n == epochs_num:
                    v_to_angles(Predicted = outp, Real = y_batch.to(device),
                                p_error_hist = hist_train_polar_error,
                                p_error_angle_cut_hist = hist_train_polar_error_angle_cut,
                                p_hist = hist_train_polar,
                                min_angle = min_angle, max_angle = max_angle) # az_hist = hist_train_azimut, to_hists = True
                    #resolution_calculation(outp,y_batch.to(device),hist = hist_train_res,to_hist = True)
            if (num%(len_seq//3) == 0):
                rand_ind=np.random.randint(0,15)
                print('Sub-epoch number = ', num)
                loss_train.append(loss.item())
                model.eval()
                testLoader = make_valset_noxyz(rand_ind,1,500, Batch_size = batch_size)
                test_loss=0
                count=0
                for x_test_batch,y_test_batch in testLoader:
                    outp = model(x_test_batch.to(device).float())
                    test_loss +=  criterion(outp,y_test_batch.to(device).float()).item()
                    count+=1
                test_loss /=count
                loss_test.append(test_loss)
                model.train()
                print("train_loss = ",loss.item(),"  val_loss = ",test_loss)
            num+=1
        scheduler_Exp.step()
        scheduler_MultiStep.step()
        
    model.eval()
    FinalLoader = make_valset_noxyz(0,-1,1, Batch_size = batch_size) # делаю  loader из всего датасета
    for x_test_batch,y_test_batch in FinalLoader:
        outp = model(x_test_batch.to(device).float())
        v_to_angles(Predicted = outp, Real = y_test_batch.to(device),
                    p_error_hist = hist_val_polar_error,
                    p_error_angle_cut_hist = hist_val_polar_error_angle_cut,
                    min_angle = min_angle, max_angle = max_angle,
                    p_hist = hist_val_polar) #, az_hist = hist_val_azimut to_hists = True,
        #resolution_calculation(outp, y_test_batch.to(device), hist = hist_val_res, to_hist = True)
    if save_weights == True:
        torch.save(model.state_dict(), path_begin + "/states/" + suffix + "model")
        torch.save(optimizer.state_dict(), path_begin + "/states/" + suffix + "opt")        
    loss_lists = [loss_train , loss_test]
    polar_hists = [hist_train_polar , hist_val_polar]
    polar_error = [hist_train_polar_error, hist_val_polar_error,
                   hist_train_polar_error_angle_cut, hist_val_polar_error_angle_cut
                  ]    
    # график лосса
    loss_plot(loss_test, loss_train , path_begin + "/Images/Loss/" + suffix + "LOSS.png", 
              save_plot )
    
    #  гистограмма ошибок  полярного угла
    res_plot(hist_train_polar_error, hist_val_polar_error, 
             path = path_begin + "/Images/Polar_Error/" + suffix+ "Polar_Error.png",
             save = save_polar_error, res_or_polar = "Polar_Error ")
     
    #  гистограмма ошибок  полярного угла для определенных углов
    res_plot(hist_train_polar_error_angle_cut, hist_val_polar_error_angle_cut, 
             path = path_begin + "/Images/Polar_Error_Angle_Cut/" + suffix+ "Polar_Error_Angle_Cut.png",
             save = save_polar_error, res_or_polar = "Polar_Error_Angle_Cut ") 
    #гистограммы углов
    angle_hist(hist_train_polar, name='train',
               path = path_begin + "/Images/Angles/" + suffix + "Angles_train.png", 
               save = save_angles)
    angle_hist(hist_val_polar, name='val',
               path = path_begin + "/Images/Angles/" + suffix + "Angles_val.png", 
               save = save_angles)
    
    model.train()
    return  loss_lists, polar_hists ,polar_error
# Out:
# cuda:0

# %%
a = torch.ones((512,5 ,32))
bigger_net_polar_relu_end_to_vec = torch.nn.Sequential(    
    torch.nn.Conv1d(5, 5,  kernel_size= 3 , stride = 1 ,padding= 1 , bias = bias_mask),
    torch.nn.BatchNorm1d(5),
    torch.nn.PReLU(),
    ResNet_Block(5), #32
    ResNet_Block(5), 
    Transition_Block(5), #16
    ResNet_Block(10),
    ResNet_Block(10), #16
    Transition_Block(10), #8
    ResNet_Block(20),
    ResNet_Block(20), 
    Transition_Block(20), #4
    ResNet_Block(40),
    ResNet_Block(40), # 4
    torch.nn.Flatten(),
    torch.nn.Linear(160,40),
    torch.nn.BatchNorm1d(40),
    torch.nn.PReLU(),
    torch.nn.Linear(40,20),
    torch.nn.BatchNorm1d(20),
    torch.nn.PReLU(),
    #torch.nn.RNNCell(20, 20),
    #torch.nn.RNNCell(20, 20),
    torch.nn.Linear(20 ,2)
    #torch.nn.ReLU()
) 


print(bigger_net_polar_relu_end_to_vec(a).shape )
print(sum(p.numel() for p in bigger_net_polar_relu_end_to_vec.parameters()   ) )
# Out:
# torch.Size([512, 2])
# 118585

# %%
model = bigger_net_polar_relu_end_to_vec.to(device)
opt = torch.optim.Adam(model.parameters(),lr=1e-2)

sch_Exp = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=0.95)
sch_MultiStep = torch.optim.lr_scheduler.MultiStepLR(opt,milestones=[6,12,18,24,30], gamma=0.8) 
loss_lists, polar_hists ,polar_error =fitting(model, sch_Exp , sch_MultiStep, opt,
                                                                       suffix = "Nu_MAE_only_polar_relu_end_to_vec",
                                                                       epochs_num = 35, batch_size =64)
# Out:
# Num of sub-epochs in Epoch =  18
#
#
#  Indeed Epoch =  1
# Sub-epoch number =  0
# train_loss =  0.08077225834131241   val_loss =  0.1105512734502554
# Sub-epoch number =  6
# train_loss =  0.04515978693962097   val_loss =  0.04941544169560075
# Sub-epoch number =  12
# train_loss =  0.04263685271143913   val_loss =  0.03716189321130514
#
#  Indeed Epoch =  2
# Sub-epoch number =  18
# train_loss =  0.04839210957288742   val_loss =  0.04353739321231842
# Sub-epoch number =  24
# train_loss =  0.04481201618909836   val_loss =  0.04087280109524727
# Sub-epoch number =  30
# train_loss =  0.0291866697371006   val_loss =  0.031176199670881033
#
#  Indeed Epoch =  3
# Sub-epoch number =  36
# train_loss =  0.035927753895521164   val_loss =  0.03269161400385201
# Sub-epoch number =  42
# train_loss =  0.03682578355073929   val_loss =  0.03245574072934687
# Sub-epoch number =  48
# train_loss =  0.03074447624385357   val_loss =  0.034559117164462805
#
#  Indeed Epoch =  4
# Sub-epoch number =  54
# train_loss =  0.02784193679690361   val_loss =  0.028427268145605922
# Sub-epoch number =  60
# train_loss =  0.02370482310652733   val_loss =  0.023350725881755352
# Sub-epoch number =  66
# train_loss =  0.024115582928061485   val_loss =  0.021556688006967306
#
#  Indeed Epoch =  5
# Sub-epoch number =  72
# train_loss =  0.02805553935468197   val_loss =  0.02259138156659901
# Sub-epoch number =  78
# train_loss =  0.02560863271355629   val_loss =  0.02062628627754748
# Sub-epoch number =  84
# train_loss =  0.024104658514261246   val_loss =  0.019645616644993424
#
#  Indeed Epoch =  6
# Sub-epoch number =  90
# train_loss =  0.024042315781116486   val_loss =  0.023243352537974715
# Sub-epoch number =  96
# train_loss =  0.024381376802921295   val_loss =  0.020013824570924044
# Sub-epoch number =  102
# train_loss =  0.02049999125301838   val_loss =  0.021307467482984066
#
#  Indeed Epoch =  7
# Sub-epoch number =  108
# train_loss =  0.02314106747508049   val_loss =  0.02254167338833213
# Sub-epoch number =  114
# train_loss =  0.020680751651525497   val_loss =  0.02090608759317547
# Sub-epoch number =  120
# train_loss =  0.020530780777335167   val_loss =  0.022257136879488826
#
#  Indeed Epoch =  8
# Sub-epoch number =  126
# train_loss =  0.018388042226433754   val_loss =  0.020670047961175442
# Sub-epoch number =  132
# train_loss =  0.01888252981007099   val_loss =  0.017610046081244946
# Sub-epoch number =  138
# train_loss =  0.018478330224752426   val_loss =  0.019791237078607082
#
#  Indeed Epoch =  9
# Sub-epoch number =  144
# train_loss =  0.01879180781543255   val_loss =  0.017051875009201467
# Sub-epoch number =  150
# train_loss =  0.01934978924691677   val_loss =  0.018749466282315552
# Sub-epoch number =  156
# train_loss =  0.017658960074186325   val_loss =  0.014800751814618707
#
#  Indeed Epoch =  10
# Sub-epoch number =  162
# train_loss =  0.019163083285093307   val_loss =  0.02183955069631338
# Sub-epoch number =  168
# train_loss =  0.026828868314623833   val_loss =  0.025141987716779113
# Sub-epoch number =  174
# train_loss =  0.021657761186361313   val_loss =  0.01848489069379866
#
#  Indeed Epoch =  11
# Sub-epoch number =  180
# train_loss =  0.01816769689321518   val_loss =  0.015755655127577484
# Sub-epoch number =  186
# train_loss =  0.017543591558933258   val_loss =  0.018831252586096525
# Sub-epoch number =  192
# train_loss =  0.019938580691814423   val_loss =  0.022343215066939592
#
#  Indeed Epoch =  12
# Sub-epoch number =  198
# train_loss =  0.04992016777396202   val_loss =  0.11332834977656603
# Sub-epoch number =  204
# train_loss =  0.019274700433015823   val_loss =  0.018297101720236242
# Sub-epoch number =  210
# train_loss =  0.020305324345827103   val_loss =  0.019402873353101313
#
#  Indeed Epoch =  13
# Sub-epoch number =  216
# train_loss =  0.020907927304506302   val_loss =  0.01910008187405765
# Sub-epoch number =  222
# train_loss =  0.022164126858115196   val_loss =  0.02430770208593458
# Sub-epoch number =  228
# train_loss =  0.019307579845190048   val_loss =  0.015997259877622128
#
#  Indeed Epoch =  14
# Sub-epoch number =  234
# train_loss =  0.018555134534835815   val_loss =  0.018268198589794338
# Sub-epoch number =  240
# train_loss =  0.016439497470855713   val_loss =  0.022062242263928056
# Sub-epoch number =  246
# train_loss =  0.020870599895715714   val_loss =  0.01641946181189269
#
#  Indeed Epoch =  15
# Sub-epoch number =  252
# train_loss =  0.017509622499346733   val_loss =  0.013316874392330647
# Sub-epoch number =  258
# train_loss =  0.018189452588558197   val_loss =  0.024345722049474716
# Sub-epoch number =  264
# train_loss =  0.017399534583091736   val_loss =  0.019926347653381526
#
#  Indeed Epoch =  16
# Sub-epoch number =  270
# train_loss =  0.016619056463241577   val_loss =  0.014858598937280476
# Sub-epoch number =  276
# train_loss =  0.017929986119270325   val_loss =  0.03161751583684236
# Sub-epoch number =  282
# train_loss =  0.01821291074156761   val_loss =  0.01709341979585588
#
#  Indeed Epoch =  17
# Sub-epoch number =  288
# train_loss =  0.01758856326341629   val_loss =  0.015513036050833762
# Sub-epoch number =  294
# train_loss =  0.015861909836530685   val_loss =  0.021615388919599354
# Sub-epoch number =  300
# train_loss =  0.018042320385575294   val_loss =  0.015911582158878446
#
#  Indeed Epoch =  18
# Sub-epoch number =  306
# train_loss =  0.01669735461473465   val_loss =  0.014318314380943775
# Sub-epoch number =  312
# train_loss =  0.01591840758919716   val_loss =  0.017794441781006753
# Sub-epoch number =  318
# train_loss =  0.017673296853899956   val_loss =  0.0209007291123271
#
#  Indeed Epoch =  19
# Sub-epoch number =  324
# train_loss =  0.01732313446700573   val_loss =  0.020184454508125782
# Sub-epoch number =  330
# train_loss =  0.015017636120319366   val_loss =  0.01574372628238052
# Sub-epoch number =  336
# train_loss =  0.017347918823361397   val_loss =  0.019683085614815354
#
#  Indeed Epoch =  20
# Sub-epoch number =  342
# train_loss =  0.016899384558200836   val_loss =  0.012956711347214878
# Sub-epoch number =  348
# train_loss =  0.01535121351480484   val_loss =  0.016122961533255875
# Sub-epoch number =  354
# train_loss =  0.01715976372361183   val_loss =  0.019305007648654282
#
#  Indeed Epoch =  21
# Sub-epoch number =  360
# train_loss =  0.016450010240077972   val_loss =  0.016464006970636547
# Sub-epoch number =  366
# train_loss =  0.01664097048342228   val_loss =  0.032008319394662976
# Sub-epoch number =  372
# train_loss =  0.016766851767897606   val_loss =  0.019997090916149318
#
#  Indeed Epoch =  22
# Sub-epoch number =  378
# train_loss =  0.016297001391649246   val_loss =  0.014572353335097432
# Sub-epoch number =  384
# train_loss =  0.015376316383481026   val_loss =  0.027575269690714777
# Sub-epoch number =  390
# train_loss =  0.017185188829898834   val_loss =  0.01697001396678388
#
#  Indeed Epoch =  23
# Sub-epoch number =  396
# train_loss =  0.01499665156006813   val_loss =  0.016763161518611014
# Sub-epoch number =  402
# train_loss =  0.018325351178646088   val_loss =  0.021531863138079643
# Sub-epoch number =  408
# train_loss =  0.016466498374938965   val_loss =  0.01627328642643988
#
#  Indeed Epoch =  24
# Sub-epoch number =  414
# train_loss =  0.016041243448853493   val_loss =  0.01673099014442414
# Sub-epoch number =  420
# train_loss =  0.014655071310698986   val_loss =  0.020192670170217752
# Sub-epoch number =  426
# train_loss =  0.01850559562444687   val_loss =  0.021455891081131995
#
#  Indeed Epoch =  25
# Sub-epoch number =  432
# train_loss =  0.016636230051517487   val_loss =  0.011729124467819929
# Sub-epoch number =  438
# train_loss =  0.01540179830044508   val_loss =  0.017443333170376718
# Sub-epoch number =  444
# train_loss =  0.01695031300187111   val_loss =  0.019194913213141263
#
#  Indeed Epoch =  26
# Sub-epoch number =  450
# train_loss =  0.017156820744276047   val_loss =  0.019319862127304077
# Sub-epoch number =  456
# train_loss =  0.014626982621848583   val_loss =  0.025070964358747005
# Sub-epoch number =  462
# train_loss =  0.01677999459207058   val_loss =  0.018454948556609452
#
#  Indeed Epoch =  27
# Sub-epoch number =  468
# train_loss =  0.016003495082259178   val_loss =  0.01738976431079209
# Sub-epoch number =  474
# train_loss =  0.01581578515470028   val_loss =  0.02365974278654903
# Sub-epoch number =  480
# train_loss =  0.01654903218150139   val_loss =  0.014511789311654866
#
#  Indeed Epoch =  28
# Sub-epoch number =  486
# train_loss =  0.015458779409527779   val_loss =  0.012544642202556133
# Sub-epoch number =  492
# train_loss =  0.014536306262016296   val_loss =  0.022627571364864707
# Sub-epoch number =  498
# train_loss =  0.018412599340081215   val_loss =  0.023987026186659932
#
#  Indeed Epoch =  29
# Sub-epoch number =  504
# train_loss =  0.01567557081580162   val_loss =  0.01591690885834396
# Sub-epoch number =  510
# train_loss =  0.014853746630251408   val_loss =  0.028834546799771488
# Sub-epoch number =  516
# train_loss =  0.016387473791837692   val_loss =  0.021939527476206422
#
#  Indeed Epoch =  30
# Sub-epoch number =  522
# train_loss =  0.015511110424995422   val_loss =  0.014263297664001584
# Sub-epoch number =  528
# train_loss =  0.015577738173305988   val_loss =  0.021093873074278235
# Sub-epoch number =  534
# train_loss =  0.016516180709004402   val_loss =  0.020413228077813983
#
#  Indeed Epoch =  31
# Sub-epoch number =  540
# train_loss =  0.01565752550959587   val_loss =  0.013662237441167235
# Sub-epoch number =  546
# train_loss =  0.015190642327070236   val_loss =  0.015560446190647781
# Sub-epoch number =  552
# train_loss =  0.01756953075528145   val_loss =  0.019626588560640812
#
#  Indeed Epoch =  32
# Sub-epoch number =  558
# train_loss =  0.01600922830402851   val_loss =  0.015632456517778337
# Sub-epoch number =  564
# train_loss =  0.014718262478709221   val_loss =  0.03157192817889154
# Sub-epoch number =  570
# train_loss =  0.017128532752394676   val_loss =  0.01977502997033298
#
#  Indeed Epoch =  33
# Sub-epoch number =  576
# train_loss =  0.015114021487534046   val_loss =  0.013765874784439802
# Sub-epoch number =  582
# train_loss =  0.014196624979376793   val_loss =  0.037335294764488935
# Sub-epoch number =  588
# train_loss =  0.017255039885640144   val_loss =  0.016471754992380738
#
#  Indeed Epoch =  34
# Sub-epoch number =  594
# train_loss =  0.016119208186864853   val_loss =  0.021326566231437027
# Sub-epoch number =  600
# train_loss =  0.014310479164123535   val_loss =  0.031223098398186266
# Sub-epoch number =  606
# train_loss =  0.01693357527256012   val_loss =  0.022941593430005014
#
#  Indeed Epoch =  35
# Sub-epoch number =  612
# train_loss =  0.01475317683070898   val_loss =  0.013099398114718497
# Sub-epoch number =  618
# train_loss =  0.014369722455739975   val_loss =  0.021367333130910993
# Sub-epoch number =  624
# train_loss =  0.017289336770772934   val_loss =  0.022695068852044642

# %%
loss_lists, polar_hists ,polar_error =fitting(model, sch_Exp , sch_MultiStep, opt,
                                                                       suffix = "Nu_MAE_only_polar_relu_end_to_vec",
                                                                       epochs_num = 1, batch_size =64,save_weights= False,save_plot = False)
# Out:
# Num of sub-epochs in Epoch =  18
#
#
#  Indeed Epoch =  1
# Sub-epoch number =  0
# train_loss =  0.01501321978867054   val_loss =  0.013165775104425848
# Sub-epoch number =  6
# train_loss =  0.015157502144575119   val_loss =  0.017664017039351165
# Sub-epoch number =  12
# train_loss =  0.01725441962480545   val_loss =  0.014805258135311306

# %%
loss_lists, polar_hists ,polar_error =fitting(model, sch_Exp , sch_MultiStep, opt,
                                                                       suffix = "Nu_MAE_only_polar_relu_end_to_vec_40",
                                                                       epochs_num = 5, batch_size =64)
# Out:
# Num of sub-epochs in Epoch =  18
#
#
#  Indeed Epoch =  1
# Sub-epoch number =  0
# train_loss =  0.015093712136149406   val_loss =  0.016543864738196135
# Sub-epoch number =  6
# train_loss =  0.014307406730949879   val_loss =  0.024724025395698845
# Sub-epoch number =  12
# train_loss =  0.01677863858640194   val_loss =  0.01923332258593291
#
#  Indeed Epoch =  2
# Sub-epoch number =  18
# train_loss =  0.016141537576913834   val_loss =  0.01843615178950131
# Sub-epoch number =  24
# train_loss =  0.014191647991538048   val_loss =  0.017966612125746906
# Sub-epoch number =  30
# train_loss =  0.01747177541255951   val_loss =  0.014593031257390976
#
#  Indeed Epoch =  3
# Sub-epoch number =  36
# train_loss =  0.015845609828829765   val_loss =  0.012281763716600835
# Sub-epoch number =  42
# train_loss =  0.015016663819551468   val_loss =  0.023091475595720112
# Sub-epoch number =  48
# train_loss =  0.017215020954608917   val_loss =  0.016923176706768572
#
#  Indeed Epoch =  4
# Sub-epoch number =  54
# train_loss =  0.014722554944455624   val_loss =  0.010869319550693035
# Sub-epoch number =  60
# train_loss =  0.01425665058195591   val_loss =  0.016236743656918406
# Sub-epoch number =  66
# train_loss =  0.01740282215178013   val_loss =  0.02256603550631553
#
#  Indeed Epoch =  5
# Sub-epoch number =  72
# train_loss =  0.015540185384452343   val_loss =  0.014136750367470086
# Sub-epoch number =  78
# train_loss =  0.014006579294800758   val_loss =  0.013650242704898119
# Sub-epoch number =  84
# train_loss =  0.017215963453054428   val_loss =  0.011706386343576014

# %%
suffix = "Nu_MAE_only_polar_relu_end_to_vec_40"
path_begin = "/home/leonov/Baikal/Cut_8_nu/APRIL/Ordered"
angle_hist(polar_hists[0], name='train',
               path = path_begin + "/Images/Angles/" + suffix + "Angles_train.png", 
               save = True)
angle_hist(polar_hists[1], name='val',
               path = path_begin + "/Images/Angles/" + suffix + "Angles_val.png", 
               save = True)

# %% [markdown]
# # Change the end -ADDED GRU CELL

# %%
a = torch.ones((512,5 ,32))
bigger_net_polar_relu_end_to_vec_GRU_END = torch.nn.Sequential(    
    torch.nn.Conv1d(5, 5,  kernel_size= 3 , stride = 1 ,padding= 1 , bias = bias_mask),
    torch.nn.BatchNorm1d(5),
    torch.nn.PReLU(),
    ResNet_Block(5), #32
    ResNet_Block(5), 
    Transition_Block(5), #16
    ResNet_Block(10),
    ResNet_Block(10), #16
    Transition_Block(10), #8
    ResNet_Block(20),
    ResNet_Block(20), 
    Transition_Block(20), #4
    ResNet_Block(40),
    ResNet_Block(40), # 4
    torch.nn.Flatten(),
    torch.nn.Linear(160,40),
    torch.nn.BatchNorm1d(40),
    torch.nn.PReLU(),
    torch.nn.Linear(40,20),
    torch.nn.BatchNorm1d(20),
    torch.nn.PReLU(),
    torch.nn.RNNCell(20, 20),
    torch.nn.RNNCell(20, 20),
    torch.nn.Linear(20 ,2)
) 
print(bigger_net_polar_relu_end_to_vec_GRU_END(a).shape )
print(sum(p.numel() for p in bigger_net_polar_relu_end_to_vec_GRU_END.parameters()   ) )

model = bigger_net_polar_relu_end_to_vec_GRU_END.to(device)
opt = torch.optim.Adam(model.parameters(),lr=8e-3)

sch_Exp = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=0.95)
sch_MultiStep = torch.optim.lr_scheduler.MultiStepLR(opt,milestones=[6,12,18,24,30], gamma=0.85) 
loss_lists, polar_hists ,polar_error =fitting(model, sch_Exp , sch_MultiStep, opt,
                                                                       suffix = "Nu_MAE_only_polar_relu_end_to_vec2",
                                                                       epochs_num = 35, batch_size =64)
# Out:
# torch.Size([512, 2])
# 120265
# torch.Size([512, 2])
# 120265
# Num of sub-epochs in Epoch =  18
#
#
#  Indeed Epoch =  1
# Sub-epoch number =  0
# train_loss =  0.07447782158851624   val_loss =  0.05641603982076049
# Sub-epoch number =  6
# train_loss =  0.05140959471464157   val_loss =  0.0505042877048254
# Sub-epoch number =  12
# train_loss =  0.0438072495162487   val_loss =  0.0382416658103466
#
#  Indeed Epoch =  2
# Sub-epoch number =  18
# train_loss =  0.051212288439273834   val_loss =  0.03935618419200182
# Sub-epoch number =  24
# train_loss =  0.046401992440223694   val_loss =  0.04009288642555475
# Sub-epoch number =  30
# train_loss =  0.038188107311725616   val_loss =  0.0301070308778435
#
#  Indeed Epoch =  3
# Sub-epoch number =  36
# train_loss =  0.03836677223443985   val_loss =  0.033867375226691365
# Sub-epoch number =  42
# train_loss =  0.030475633218884468   val_loss =  0.022958734771236777
# Sub-epoch number =  48
# train_loss =  0.025377031415700912   val_loss =  0.02541455370374024
#
#  Indeed Epoch =  4
# Sub-epoch number =  54
# train_loss =  0.0312538668513298   val_loss =  0.024544333340600133
# Sub-epoch number =  60
# train_loss =  0.03372015431523323   val_loss =  0.02137452200986445
# Sub-epoch number =  66
# train_loss =  0.0284343883395195   val_loss =  0.027745362604036927
#
#  Indeed Epoch =  5
# Sub-epoch number =  72
# train_loss =  0.03221069648861885   val_loss =  0.026712720282375813
# Sub-epoch number =  78
# train_loss =  0.027389878407120705   val_loss =  0.01952595473267138
# Sub-epoch number =  84
# train_loss =  0.024125300347805023   val_loss =  0.02886662632226944
#
#  Indeed Epoch =  6
# Sub-epoch number =  90
# train_loss =  0.02762424945831299   val_loss =  0.022306857630610466
# Sub-epoch number =  96
# train_loss =  0.031003404408693314   val_loss =  0.022039645351469517
# Sub-epoch number =  102
# train_loss =  0.023367563262581825   val_loss =  0.019982620608061552
#
#  Indeed Epoch =  7
# Sub-epoch number =  108
# train_loss =  0.024726463481783867   val_loss =  0.018252122914418578
# Sub-epoch number =  114
# train_loss =  0.025131748989224434   val_loss =  0.016007302794605494
# Sub-epoch number =  120
# train_loss =  0.02431383915245533   val_loss =  0.02086497249547392
#
#  Indeed Epoch =  8
# Sub-epoch number =  126
# train_loss =  0.02261551283299923   val_loss =  0.018434116151183844
# Sub-epoch number =  132
# train_loss =  0.025683891028165817   val_loss =  0.02110961708240211
# Sub-epoch number =  138
# train_loss =  0.022703861817717552   val_loss =  0.02176659321412444
#
#  Indeed Epoch =  9
# Sub-epoch number =  144
# train_loss =  0.024585377424955368   val_loss =  0.01960864383727312
# Sub-epoch number =  150
# train_loss =  0.02263319492340088   val_loss =  0.01848386530764401
# Sub-epoch number =  156
# train_loss =  0.02022867277264595   val_loss =  0.01756897009909153
# Sub-epoch number =  168
# train_loss =  0.02662668749690056   val_loss =  0.017093137372285128
# Sub-epoch number =  174
# train_loss =  0.018570585176348686   val_loss =  0.01646579639054835
#
#  Indeed Epoch =  11
# Sub-epoch number =  180
# train_loss =  0.01999453827738762   val_loss =  0.016966803232207894
# Sub-epoch number =  186
# train_loss =  0.026672571897506714   val_loss =  0.02103568986058235
# Sub-epoch number =  192
# train_loss =  0.01756105199456215   val_loss =  0.014072249527089298
#
#  Indeed Epoch =  12
# Sub-epoch number =  198
# train_loss =  0.02163989655673504   val_loss =  0.01865172095131129
# Sub-epoch number =  204
# train_loss =  0.024632960557937622   val_loss =  0.01767943787854165
# Sub-epoch number =  210
# train_loss =  0.017548896372318268   val_loss =  0.015283409971743822
#
#  Indeed Epoch =  13
# Sub-epoch number =  216
# train_loss =  0.020296838134527206   val_loss =  0.015695313806645572
# Sub-epoch number =  222
# train_loss =  0.020749980583786964   val_loss =  0.01655069086700678
# Sub-epoch number =  228
# train_loss =  0.017745571210980415   val_loss =  0.016512481961399317
#
#  Indeed Epoch =  14
# Sub-epoch number =  234
# train_loss =  0.020137835294008255   val_loss =  0.015028530266135931
# Sub-epoch number =  240
# train_loss =  0.019534096121788025   val_loss =  0.01703591097611934
# Sub-epoch number =  246
# train_loss =  0.016427520662546158   val_loss =  0.016274634865112603
#
#  Indeed Epoch =  15
# Sub-epoch number =  252
# train_loss =  0.01952049881219864   val_loss =  0.01428936270531267
# Sub-epoch number =  258
# train_loss =  0.019897889345884323   val_loss =  0.017898537567816675
# Sub-epoch number =  264
# train_loss =  0.017599523067474365   val_loss =  0.014706075075082481
#
#  Indeed Epoch =  16
# Sub-epoch number =  270
# train_loss =  0.019053300842642784   val_loss =  0.014414346544072032
# Sub-epoch number =  276
# train_loss =  0.018953293561935425   val_loss =  0.018944841576740146
# Sub-epoch number =  282
# train_loss =  0.016704432666301727   val_loss =  0.01457794290035963
#
#  Indeed Epoch =  17
# Sub-epoch number =  288
# train_loss =  0.019919710233807564   val_loss =  0.01597466168459505
# Sub-epoch number =  294
# train_loss =  0.019488098099827766   val_loss =  0.01663335505872965
# Sub-epoch number =  300
# train_loss =  0.016885634511709213   val_loss =  0.013926636893302202
#
#  Indeed Epoch =  18
# Sub-epoch number =  306
# train_loss =  0.0174667127430439   val_loss =  0.012999855331145227
# Sub-epoch number =  312
# train_loss =  0.018336692824959755   val_loss =  0.015782602014951408
# Sub-epoch number =  318
# train_loss =  0.01694572903215885   val_loss =  0.01348291290923953
#
#  Indeed Epoch =  19
# Sub-epoch number =  324
# train_loss =  0.01731090247631073   val_loss =  0.012888959143310785
# Sub-epoch number =  330
# train_loss =  0.018349094316363335   val_loss =  0.0171622964553535
# Sub-epoch number =  336
# train_loss =  0.01710616424679756   val_loss =  0.016336824861355126
#
#  Indeed Epoch =  20
# Sub-epoch number =  342
# train_loss =  0.01826821267604828   val_loss =  0.014268013532273471
# Sub-epoch number =  348
# train_loss =  0.018171153962612152   val_loss =  0.014869459671899676
# Sub-epoch number =  354
# train_loss =  0.01650930382311344   val_loss =  0.012325289426371455
#
#  Indeed Epoch =  21
# Sub-epoch number =  360
# train_loss =  0.017138991504907608   val_loss =  0.01408732240088284
# Sub-epoch number =  366
# train_loss =  0.017174948006868362   val_loss =  0.012884589261375368
# Sub-epoch number =  372
# train_loss =  0.016192957758903503   val_loss =  0.012855148408561945
#
#  Indeed Epoch =  22
# Sub-epoch number =  378
# train_loss =  0.016286911442875862   val_loss =  0.013925198349170387
# Sub-epoch number =  384
# train_loss =  0.017796967178583145   val_loss =  0.01343389693647623
# Sub-epoch number =  390
# train_loss =  0.015878207981586456   val_loss =  0.013127256417647004
#
#  Indeed Epoch =  23
# Sub-epoch number =  396
# train_loss =  0.015902118757367134   val_loss =  0.01390714175067842
# Sub-epoch number =  402
# train_loss =  0.016764864325523376   val_loss =  0.014030864462256432
# Sub-epoch number =  408
# train_loss =  0.015602916479110718   val_loss =  0.014187419088557363
#
#  Indeed Epoch =  24
# Sub-epoch number =  414
# train_loss =  0.016158591955900192   val_loss =  0.012058527441695333
# Sub-epoch number =  420
# train_loss =  0.01743992790579796   val_loss =  0.015819956664927304
# Sub-epoch number =  426
# train_loss =  0.016096459701657295   val_loss =  0.012340512126684189
#
#  Indeed Epoch =  25
# Sub-epoch number =  432
# train_loss =  0.01618613861501217   val_loss =  0.013096302165649831
# Sub-epoch number =  438
# train_loss =  0.016795866191387177   val_loss =  0.012631869758479297
# Sub-epoch number =  444
# train_loss =  0.015571805648505688   val_loss =  0.01447125687263906
#
#  Indeed Epoch =  26
# Sub-epoch number =  450
# train_loss =  0.01570497825741768   val_loss =  0.013260937994346023
# Sub-epoch number =  456
# train_loss =  0.016717005521059036   val_loss =  0.015257281600497663
# Sub-epoch number =  462
# train_loss =  0.015807384625077248   val_loss =  0.013363865669816732
#
#  Indeed Epoch =  27
# Sub-epoch number =  468
# train_loss =  0.015822194516658783   val_loss =  0.013302617473527789
# Sub-epoch number =  474
# train_loss =  0.016710098832845688   val_loss =  0.013881184277124703
# Sub-epoch number =  480
# train_loss =  0.01572437584400177   val_loss =  0.014331475831568241
#
#  Indeed Epoch =  28
# Sub-epoch number =  486
# train_loss =  0.01533888466656208   val_loss =  0.01202575012575835
# Sub-epoch number =  492
# train_loss =  0.016758671030402184   val_loss =  0.012020682916045189
# Sub-epoch number =  498
# train_loss =  0.01571013405919075   val_loss =  0.01384705025702715
#
#  Indeed Epoch =  29
# Sub-epoch number =  504
# train_loss =  0.015281408093869686   val_loss =  0.014451358700171113
# Sub-epoch number =  510
# train_loss =  0.015917286276817322   val_loss =  0.01274091494269669
# Sub-epoch number =  516
# train_loss =  0.015284130349755287   val_loss =  0.012034872896037996
#
#  Indeed Epoch =  30
# Sub-epoch number =  522
# train_loss =  0.01565636321902275   val_loss =  0.014326550415717065
# Sub-epoch number =  528
# train_loss =  0.016584759578108788   val_loss =  0.015049493522383273
# Sub-epoch number =  534
# train_loss =  0.014660604298114777   val_loss =  0.013791878940537572
#
#  Indeed Epoch =  31
# Sub-epoch number =  540
# train_loss =  0.015431099571287632   val_loss =  0.014275721390731633
# Sub-epoch number =  546
# train_loss =  0.01644984446465969   val_loss =  0.013775531086139381
# Sub-epoch number =  552
# train_loss =  0.015546583570539951   val_loss =  0.01366988243535161
#
#  Indeed Epoch =  32
# Sub-epoch number =  558
# train_loss =  0.015875980257987976   val_loss =  0.010739264776930213
# Sub-epoch number =  564
# train_loss =  0.01635635644197464   val_loss =  0.013088005362078547
# Sub-epoch number =  570
# train_loss =  0.015382343903183937   val_loss =  0.013089198502711952
#
#  Indeed Epoch =  33
# Sub-epoch number =  576
# train_loss =  0.015514778904616833   val_loss =  0.012905806535854936
# Sub-epoch number =  582
# train_loss =  0.016056561842560768   val_loss =  0.01136272493749857
# Sub-epoch number =  588
# train_loss =  0.015731308609247208   val_loss =  0.010930703952908516
#
#  Indeed Epoch =  34
# Sub-epoch number =  594
# train_loss =  0.015678444877266884   val_loss =  0.012312898179516196
# Sub-epoch number =  600
# train_loss =  0.01658529043197632   val_loss =  0.013294898672029376
# Sub-epoch number =  606
# train_loss =  0.015496469102799892   val_loss =  0.012650887481868267
#
#  Indeed Epoch =  35
# Sub-epoch number =  612
# train_loss =  0.015946704894304276   val_loss =  0.012755686300806701
# Sub-epoch number =  618
# train_loss =  0.016249116510152817   val_loss =  0.014797787764109671
# Sub-epoch number =  624
# train_loss =  0.01529630832374096   val_loss =  0.012341808760538697

# %%
loss_lists, polar_hists ,polar_error =fitting(model, sch_Exp , sch_MultiStep, opt,
                                                                       suffix = "Nu_MAE_only_polar_relu_end_to_vec2_40ep",
                                                                       epochs_num = 5, batch_size =64)
# Out:
# Num of sub-epochs in Epoch =  18
#
#
#  Indeed Epoch =  1
# Sub-epoch number =  0
# train_loss =  0.016007594764232635   val_loss =  0.011482111760415137

# %% [markdown]
# # SeLu
